# %%
import pandas as pd
import numpy as np

# %%
pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', None)
concept_nutrition = pd.read_csv('nutrition.csv',\
                                 error_bad_lines= False, delimiter = '\t',nrows=100000)

#pd.read_csv("en.openfoodfacts.org.products.csv",error_bad_lines= False,delimiter='\t')
# Out:
# C:\Users\Imen\anaconda31\lib\site-packages\IPython\core\interactiveshell.py:3165: DtypeWarning: Columns (0,13,27,28,29,31,52) have mixed types.Specify dtype option on import or set low_memory=False.
#   has_raised = await self.run_ast_nodes(code_ast.body, cell_name,

# %%
concept_nutrition.head()
# Out:
#                    code                                                url  \
# 0     00000000000000225  http://world-en.openfoodfacts.org/product/0000...
# 1  00000000000003429145  http://world-en.openfoodfacts.org/product/0000...
# 2         0000000000017  http://world-en.openfoodfacts.org/product/0000...
# 3         0000000000031  http://world-en.openfoodfacts.org/product/0000...
# 4    000000000003327986  http://world-en.openfoodfacts.org/product/0000...
#
#           creator   created_t      created_datetime  last_modified_t  \
# 0  nutrinet-sante  1623855208  2021-06-16T14:53:28Z       1623855209
# 1         kiliweb  1630483911  2021-09-01T08:11:51Z       1630484064
# 2         kiliweb  1529059080  2018-06-15T10:38:00Z       1561463718
# 3        isagoofy  1539464774  2018-10-13T21:06:14Z       1539464817
# 4         kiliweb  1574175736  2019-11-19T15:02:16Z       1624390765
#
#   last_modified_datetime               product_name  abbreviated_product_name  \
# ...

# %%
concept_nutrition.shape

# %%
concept_nutrition.isnull().sum()

# %%
new_df= concept_nutrition[['code','product_name', 'brands',\
                           'energy_100g', 'fat_100g','sugars_100g',\
                           'proteins_100g', 'salt_100g','stores', 'countries',\
                           'pnns_groups_1','pnns_groups_2',\
                           'energy-kcal_100g', 'nutrition-score-fr_100g']]

# %%
new_df.head(10)

# %%
new_df2 = new_df.head(10000)

# %%
new_df2.shape

# %%
new_df2.head(5)

# %%
new_df2.info()

# %%
new_df2['energy_100g'].head().dtype

# %%
#new_df2[['fat_100g','sugars_100g','proteins_100g', 'salt_100g']].fillna(0, axis = 0)

# %%
value = {"fat_100g": 0,
"sugars_100g" : 0,
"proteins_100g": 0,
"salt_100g": 0,
"energy-kcal_100g": 0,
"energy_100g": 0}
df_fill = df_nutrition.fillna(value)

# %%
df_fill.head()

# %%
df_fill_full= df_fill[['code','product_name', 'brands',\
                       'fat_100g','sugars_100g',\
                       'proteins_100g', 'salt_100g', 'countries','energy-kcal_100g',\
                       'nutrition-score-fr_100g']]

# %%
#df_fill_full.to_csv('df_final.csv',index =False)

# %%
df_fill_full.head(10)
